# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# Import API key
from gitignore.api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create the list to Store the API called data
city_name = []
max_temperature = []
humidity = []
cloud = []
wind = []
country = []
date = []
lat = []
lon = []

# Set the initial city number as 0
i =0

# List the base_url for later API call
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Print the APT Call data
print("Beginning data Retrieval")
print("-----------------------------")
for city in cities:
    complete_url = base_url + "units=" + "Imperial" + "&APPID=" + api_key + "&q=" + city
    response = requests.get(complete_url)
    x = response.json()
    try:
        # Store the API call data into the created list
        city_name.append(x["name"])
        lat.append(x["coord"]["lat"])
        lon.append(x["coord"]["lon"])
        country.append(x["sys"]["country"])
        max_temperature.append(x["main"]["temp_max"]) 
        humidity.append(x["main"]["humidity"])
        cloud.append(x["clouds"]["all"])
        wind.append(x["wind"]["speed"])
        date.append(x["dt"])
        print(f"Processing Record {i} | {city}")
        #print(complete_url)
        i = i + 1
        
    # skip the key errors to avoid the calling stop
    except KeyError:
        print(" City Not Found. Skipping...")        
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning data Retrieval
# -----------------------------
# Processing Record 0 | blackwater
# Processing Record 1 | kisesa
# Processing Record 2 | lompoc
# Processing Record 3 | yellowknife
# Processing Record 4 | bilibino
# Processing Record 5 | port elizabeth
# Processing Record 6 | tuatapere
# Processing Record 7 | thompson
# Processing Record 8 | nemuro
# Processing Record 9 | souillac
# Processing Record 10 | butaritari
# Processing Record 11 | rikitea
# Processing Record 12 | duku
# Processing Record 13 | punta arenas
# Processing Record 14 | north bend
# Processing Record 15 | vaini
#  City Not Found. Skipping...
# Processing Record 16 | busselton
# Processing Record 17 | airai
# Processing Record 18 | ous
# Processing Record 19 | bluff
# Processing Record 20 | nikolskoye
# Processing Record 21 | madimba
# Processing Record 22 | barrow
# Processing Record 23 | lincoln
# Processing Record 24 | sao joao da barra
# Processing Record 25 | laminusa
# Processing Record 26 | cape town
# Processing Record 27 | jamestown
# Processing Record 28 | negombo
# Processing Record 29 | atuona
# Processing Record 30 | bowen
# Processing Record 31 | kahului
# Processing Record 32 | carnarvon
# Processing Record 33 | ukiah
# Processing Record 34 | longyearbyen
# Processing Record 35 | qeshm
# Processing Record 36 | port moresby
# Processing Record 37 | santa helena de goias
# Processing Record 38 | kapaa
# Processing Record 39 | ngawi
# Processing Record 40 | avarua
# Processing Record 41 | hermanus
# Processing Record 42 | leshukonskoye
#  City Not Found. Skipping...
# Processing Record 43 | tuktoyaktuk
# Processing Record 44 | chuy
# Processing Record 45 | severo-kurilsk
# Processing Record 46 | mapiripan
# Processing Record 47 | onega
# Processing Record 48 | camacari
# Processing Record 49 | orlik
# Processing Record 50 | pervomayskoye
# Processing Record 51 | khatanga
# Processing Record 52 | ushuaia
# Processing Record 53 | saskylakh
# Processing Record 54 | lebu
# Processing Record 55 | bredasdorp
# Processing Record 56 | mataura
# Processing Record 57 | turukhansk
# Processing Record 58 | bilma
# Processing Record 59 | mackenzie
# Processing Record 60 | elko
# Processing Record 61 | voh
# Processing Record 62 | zhangjiakou
# Processing Record 63 | roald
# Processing Record 64 | puerto ayora
# Processing Record 65 | cadillac
# Processing Record 66 | biak
# Processing Record 67 | sedona
# Processing Record 68 | zhezkazgan
# Processing Record 69 | piterka
#  City Not Found. Skipping...
# Processing Record 70 | padang
# Processing Record 71 | grenfell
# Processing Record 72 | tamandare
# Processing Record 73 | ponta do sol
#  City Not Found. Skipping...
# Processing Record 74 | georgetown
# Processing Record 75 | leningradskiy
# Processing Record 76 | daru
# Processing Record 77 | faanui
# Processing Record 78 | asosa
# Processing Record 79 | mecca
# Processing Record 80 | atar
#  City Not Found. Skipping...
# Processing Record 81 | albany
# Processing Record 82 | bambous virieux
# Processing Record 83 | castro
# Processing Record 84 | katsuura
# Processing Record 85 | aswan
# Processing Record 86 | victoria
# Processing Record 87 | straumen
# Processing Record 88 | redmond
# Processing Record 89 | new norfolk
# Processing Record 90 | oistins
# Processing Record 91 | perry
# Processing Record 92 | najran
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 93 | saint anthony
# Processing Record 94 | krapina
# Processing Record 95 | hoshcha
# Processing Record 96 | ribeira grande
# Processing Record 97 | hilo
#  City Not Found. Skipping...
# Processing Record 98 | octeville
# Processing Record 99 | hervey bay
# Processing Record 100 | san patricio
# Processing Record 101 | kruisfontein
# Processing Record 102 | den helder
# Processing Record 103 | shambu
# Processing Record 104 | palestine
# Processing Record 105 | florianopolis
# Processing Record 106 | daman
#  City Not Found. Skipping...
# Processing Record 107 | sur
# Processing Record 108 | hobart
# Processing Record 109 | comodoro rivadavia
# Processing Record 110 | tanete
# Processing Record 111 | stettler
# Processing Record 112 | port lincoln
# Processing Record 113 | broome
# Processing Record 114 | portland
#  City Not Found. Skipping...
# Processing Record 115 | kaeo
# Processing Record 116 | collie
# Processing Record 117 | zyryanka
# Processing Record 118 | pangnirtung
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 119 | costa rica
# Processing Record 120 | tymovskoye
# Processing Record 121 | mount isa
# Processing Record 122 | tiksi
#  City Not Found. Skipping...
# Processing Record 123 | ipixuna
# Processing Record 124 | el retorno
# Processing Record 125 | tasiilaq
#  City Not Found. Skipping...
# Processing Record 126 | sitka
# Processing Record 127 | sept-iles
# Processing Record 128 | alyangula
# Processing Record 129 | vaitape
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 130 | oconomowoc
# Processing Record 131 | jumla
# Processing Record 132 | nador
# Processing Record 133 | east london
# Processing Record 134 | natal
# Processing Record 135 | presidente medici
# Processing Record 136 | oriximina
#  City Not Found. Skipping...
# Processing Record 137 | geraldton
# Processing Record 138 | novyy urengoy
# Processing Record 139 | dingle
# Processing Record 140 | banda aceh
# Processing Record 141 | sao miguel do araguaia
# Processing Record 142 | windsor
#  City Not Found. Skipping...
# Processing Record 143 | kavieng
# Processing Record 144 | saint george
# Processing Record 145 | claveria
# Processing Record 146 | mehamn
# Processing Record 147 | ornskoldsvik
# Processing Record 148 | laguna
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 149 | egvekinot
# Processing Record 150 | guspini
# Processing Record 151 | lagoa
#  City Not Found. Skipping...
# Processing Record 152 | talnakh
# Processing Record 153 | avera
# Processing Record 154 | lemoore
# Processing Record 155 | naze
# Processing Record 156 | mahebourg
# Processing Record 157 | cayenne
# Processing Record 158 | tomatlan
# Processing Record 159 | zeya
#  City Not Found. Skipping...
# Processing Record 160 | boende
# Processing Record 161 | isla mujeres
# Processing Record 162 | hasaki
#  City Not Found. Skipping...
# Processing Record 163 | chik
# Processing Record 164 | kamina
# Processing Record 165 | isangel
# Processing Record 166 | port alfred
# Processing Record 167 | magadan
# Processing Record 168 | perdika
# Processing Record 169 | norman wells
# Processing Record 170 | anadyr
# Processing Record 171 | paita
# Processing Record 172 | luderitz
# Processing Record 173 | mokhotlong
# Processing Record 174 | mar del plata
#  City Not Found. Skipping...
# Processing Record 175 | pevek
# Processing Record 176 | eldorado
# Processing Record 177 | kavaratti
# Processing Record 178 | salym
# Processing Record 179 | dhidhdhoo
# Processing Record 180 | dikson
# Processing Record 181 | smithville
# Processing Record 182 | konevo
# Processing Record 183 | zhigansk
# Processing Record 184 | hithadhoo
# Processing Record 185 | raudeberg
# Processing Record 186 | muhos
# Processing Record 187 | galle
# Processing Record 188 | ejura
# Processing Record 189 | castilho
# Processing Record 190 | ostrovnoy
# Processing Record 191 | san isidro
# Processing Record 192 | waddan
# Processing Record 193 | nuuk
# Processing Record 194 | truckee
# Processing Record 195 | pascagoula
# Processing Record 196 | henties bay
# Processing Record 197 | north platte
# Processing Record 198 | bonavista
# Processing Record 199 | oranjemund
# Processing Record 200 | lorengau
# Processing Record 201 | liberty
# Processing Record 202 | iqaluit
# Processing Record 203 | hami
# Processing Record 204 | mangai
# Processing Record 205 | dustlik
# Processing Record 206 | qaanaaq
# Processing Record 207 | cabo san lucas
# Processing Record 208 | yerbogachen
# Processing Record 209 | uarini
#  City Not Found. Skipping...
# Processing Record 210 | la ronge
# Processing Record 211 | touros
# Processing Record 212 | lata
#  City Not Found. Skipping...
# Processing Record 213 | saint-philippe
# Processing Record 214 | ilulissat
#  City Not Found. Skipping...
# Processing Record 215 | tezu
# Processing Record 216 | assare
# Processing Record 217 | nigde
# Processing Record 218 | tralee
# Processing Record 219 | port keats
# Processing Record 220 | ada
# Processing Record 221 | tynaarlo
# Processing Record 222 | booue
#  City Not Found. Skipping...
# Processing Record 223 | salalah
# Processing Record 224 | carutapera
# Processing Record 225 | umea
# Processing Record 226 | swan hill
# Processing Record 227 | los llanos de aridane
# Processing Record 228 | alugan
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 229 | along
# Processing Record 230 | ambilobe
# Processing Record 231 | coquimbo
# Processing Record 232 | provideniya
#  City Not Found. Skipping...
# Processing Record 233 | moshi
# Processing Record 234 | price
# Processing Record 235 | kodiak
# Processing Record 236 | mingguang
# Processing Record 237 | cherskiy
# Processing Record 238 | krasnovishersk
# Processing Record 239 | coulommiers
# Processing Record 240 | srandakan
# Processing Record 241 | gamba
# Processing Record 242 | harper
# Processing Record 243 | saldanha
# Processing Record 244 | pisco
#  City Not Found. Skipping...
# Processing Record 245 | kiri buru
# Processing Record 246 | taoudenni
# Processing Record 247 | guerrero negro
# Processing Record 248 | paamiut
# Processing Record 249 | emerald
# Processing Record 250 | tiznit
# Processing Record 251 | arlit
# Processing Record 252 | ancud
# Processing Record 253 | veraval
# Processing Record 254 | tabuk
# Processing Record 255 | plouzane
# Processing Record 256 | calabar
#  City Not Found. Skipping...
# Processing Record 257 | salisbury
# Processing Record 258 | miraflores
# Processing Record 259 | san andres
# Processing Record 260 | san javier
# Processing Record 261 | roma
# Processing Record 262 | gardner
# Processing Record 263 | kiama
#  City Not Found. Skipping...
# Processing Record 264 | cabedelo
# Processing Record 265 | abha
# Processing Record 266 | sinnamary
# Processing Record 267 | tigre
# Processing Record 268 | te anau
# Processing Record 269 | udachnyy
# Processing Record 270 | grindavik
#  City Not Found. Skipping...
# Processing Record 271 | davila
# Processing Record 272 | port shepstone
# Processing Record 273 | junin
# Processing Record 274 | whitehorse
# Processing Record 275 | atikokan
# Processing Record 276 | kupang
# Processing Record 277 | moroni
# Processing Record 278 | rebrikha
# Processing Record 279 | nkhata bay
# Processing Record 280 | ewa beach
# Processing Record 281 | ilhabela
# Processing Record 282 | hamilton
#  City Not Found. Skipping...
# Processing Record 283 | khorol
# Processing Record 284 | oktyabrskiy
# Processing Record 285 | coahuayana
# Processing Record 286 | kogon
# Processing Record 287 | camacha
# Processing Record 288 | uyuni
# Processing Record 289 | arica
# Processing Record 290 | antofagasta
# Processing Record 291 | shebunino
# Processing Record 292 | kaitangata
# Processing Record 293 | key west
# Processing Record 294 | muhororo
# Processing Record 295 | chivay
# Processing Record 296 | cururupu
# Processing Record 297 | verkhoyansk
# Processing Record 298 | anloga
# Processing Record 299 | dondo
# Processing Record 300 | kochki
# Processing Record 301 | arraial do cabo
#  City Not Found. Skipping...
# Processing Record 302 | nampula
# Processing Record 303 | shingu
# Processing Record 304 | cacule
# Processing Record 305 | coihaique
# Processing Record 306 | kamaishi
# Processing Record 307 | bonthe
# Processing Record 308 | makhu
# Processing Record 309 | cap malheureux
# Processing Record 310 | chokurdakh
# Processing Record 311 | kawerau
# Processing Record 312 | muros
# Processing Record 313 | bozova
# Processing Record 314 | upernavik
# Processing Record 315 | ust-kuyga
# Processing Record 316 | el rosario
# Processing Record 317 | alofi
# Processing Record 318 | saint-junien
# Processing Record 319 | mujiayingzi
#  City Not Found. Skipping...
# Processing Record 320 | jasper
# Processing Record 321 | saint-pierre
# Processing Record 322 | paysandu
# Processing Record 323 | hashtrud
# Processing Record 324 | albanel
# Processing Record 325 | gilgit
# Processing Record 326 | beloha
# Processing Record 327 | pandan
# Processing Record 328 | yaan
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 329 | saint-francois
# Processing Record 330 | puerto suarez
# Processing Record 331 | qasigiannguit
# Processing Record 332 | montepuez
# Processing Record 333 | quatre cocos
# Processing Record 334 | mut
# Processing Record 335 | maceio
# Processing Record 336 | kumi
# Processing Record 337 | solnechnyy
# Processing Record 338 | cidreira
# Processing Record 339 | fairlie
# Processing Record 340 | ocher
# Processing Record 341 | westport
# Processing Record 342 | kesova gora
# Processing Record 343 | mitu
# Processing Record 344 | bethel
# Processing Record 345 | kieta
# Processing Record 346 | srivardhan
# Processing Record 347 | ormara
# Processing Record 348 | port hedland
# Processing Record 349 | derzhavinsk
# Processing Record 350 | viedma
# Processing Record 351 | puerto colombia
# Processing Record 352 | namibe
# Processing Record 353 | zatyshshya
# Processing Record 354 | bridlington
# Processing Record 355 | port blair
# Processing Record 356 | lazurne
# Processing Record 357 | rongcheng
# Processing Record 358 | nguruka
# Processing Record 359 | kuusankoski
# Processing Record 360 | beringovskiy
# Processing Record 361 | hailar
# Processing Record 362 | clyde river
# Processing Record 363 | green river
# Processing Record 364 | shubarshi
# Processing Record 365 | ardakan
# Processing Record 366 | hofn
#  City Not Found. Skipping...
# Processing Record 367 | vostok
# Processing Record 368 | bacong
# Processing Record 369 | vannes
# Processing Record 370 | paris
# Processing Record 371 | moradabad
# Processing Record 372 | vicente guerrero
# Processing Record 373 | manadhoo
# Processing Record 374 | esperance
# Processing Record 375 | eyl
#  City Not Found. Skipping...
# Processing Record 376 | bako
# Processing Record 377 | gigmoto
#  City Not Found. Skipping...
# Processing Record 378 | garowe
# Processing Record 379 | oranjestad
# Processing Record 380 | rendsburg
# Processing Record 381 | paragominas
# Processing Record 382 | bubaque
# Processing Record 383 | vila velha
#  City Not Found. Skipping...
# Processing Record 384 | matara
# Processing Record 385 | kutulik
# Processing Record 386 | walvis bay
# Processing Record 387 | kosikha
# Processing Record 388 | madras
# Processing Record 389 | lasa
# Processing Record 390 | makat
# Processing Record 391 | san vicente
# Processing Record 392 | kuala pilah
# Processing Record 393 | vanavara
# Processing Record 394 | la tijera
# Processing Record 395 | matagami
# Processing Record 396 | svetlogorsk
# Processing Record 397 | verkhnevilyuysk
# Processing Record 398 | ouesso
# Processing Record 399 | leh
# Processing Record 400 | hua hin
# Processing Record 401 | aklavik
# Processing Record 402 | quzhou
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 403 | aksu
# Processing Record 404 | itarema
# Processing Record 405 | santa cruz cabralia
# Processing Record 406 | jackson
# Processing Record 407 | bandarbeyla
# Processing Record 408 | teguise
# Processing Record 409 | dongobesh
# Processing Record 410 | valparaiso
# Processing Record 411 | ereymentau
# Processing Record 412 | omalur
# Processing Record 413 | orzu
# Processing Record 414 | manosque
# Processing Record 415 | soledade
# Processing Record 416 | palana
# Processing Record 417 | umkomaas
# Processing Record 418 | riyadh
# Processing Record 419 | south shields
#  City Not Found. Skipping...
# Processing Record 420 | colares
# Processing Record 421 | elk plain
# Processing Record 422 | njombe
# Processing Record 423 | lodja
# Processing Record 424 | khani
# Processing Record 425 | meulaboh
# Processing Record 426 | salinopolis
# Processing Record 427 | kathu
# Processing Record 428 | louga
# Processing Record 429 | zhangye
# Processing Record 430 | nancha
# Processing Record 431 | peniche
# Processing Record 432 | kapit
# Processing Record 433 | erzin
# Processing Record 434 | cascais
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 435 | pauini
# Processing Record 436 | carroll
# Processing Record 437 | ruidoso
# Processing Record 438 | luchegorsk
# Processing Record 439 | pinawa
# Processing Record 440 | krasnyy chikoy
# Processing Record 441 | komsomolskiy
# Processing Record 442 | amuntai
# Processing Record 443 | maroantsetra
# Processing Record 444 | kalianget
#  City Not Found. Skipping...
# Processing Record 445 | fortuna
# Processing Record 446 | abnub
# Processing Record 447 | loa janan
# Processing Record 448 | kidal
# Processing Record 449 | narsaq
# Processing Record 450 | brae
# Processing Record 451 | vestmanna
# Processing Record 452 | torbay
# Processing Record 453 | homer
# Processing Record 454 | pontarlier
# Processing Record 455 | greenville
# Processing Record 456 | khor
# Processing Record 457 | ciudad bolivar
# Processing Record 458 | patea
# Processing Record 459 | xinzhou
# Processing Record 460 | richards bay
#  City Not Found. Skipping...
# Processing Record 461 | flinders
# Processing Record 462 | svecha
#  City Not Found. Skipping...
# Processing Record 463 | providencia
# Processing Record 464 | frankfort
# Processing Record 465 | kutum
# Processing Record 466 | hun
# Processing Record 467 | sangar
# Processing Record 468 | magrath
# Processing Record 469 | mandalgovi
# Processing Record 470 | tynda
# Processing Record 471 | masalli
# Processing Record 472 | manati
# Processing Record 473 | troitskoye
# Processing Record 474 | trincomalee
# Processing Record 475 | rostovka
# Processing Record 476 | matadi
# Processing Record 477 | sioux lookout
# Processing Record 478 | husavik
# Processing Record 479 | havre
# Processing Record 480 | reims
# Processing Record 481 | yar-sale
# Processing Record 482 | acapulco
# Processing Record 483 | fare
# Processing Record 484 | kpalime
#  City Not Found. Skipping...
# Processing Record 485 | banikoara
#  City Not Found. Skipping...
# Processing Record 486 | neuquen
# Processing Record 487 | maragogi
# Processing Record 488 | fuerte olimpo
#  City Not Found. Skipping...
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 489 | ketchikan
# Processing Record 490 | mae hong son
# Processing Record 491 | port-cartier
# Processing Record 492 | caravelas
# Processing Record 493 | tommot
# Processing Record 494 | klaeng
#  City Not Found. Skipping...
# Processing Record 495 | popondetta
# Processing Record 496 | jaru
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 497 | puerto escondido
# Processing Record 498 | modasa
# Processing Record 499 | san quintin
# Processing Record 500 | tevaitoa
# Processing Record 501 | pervomayskiy
# Processing Record 502 | surt
# Processing Record 503 | storforshei
# Processing Record 504 | neryungri
# Processing Record 505 | ratnagiri
# Processing Record 506 | ribas do rio pardo
# Processing Record 507 | rabo de peixe
# Processing Record 508 | brookside
# Processing Record 509 | klaksvik
# Processing Record 510 | constitucion
# Processing Record 511 | bud
# Processing Record 512 | pasinler
# Processing Record 513 | codrington
# Processing Record 514 | pacific grove
# Processing Record 515 | chincha alta
# Processing Record 516 | kuznechnoye
# Processing Record 517 | beckley
# Processing Record 518 | feijo
# Processing Record 519 | kondagaon
# Processing Record 520 | ierapetra
# Processing Record 521 | mega
# Processing Record 522 | nyanza
# Processing Record 523 | kedrovyy
# Processing Record 524 | batagay
# Processing Record 525 | methoni
# Processing Record 526 | meadow lake
# Processing Record 527 | strezhevoy
# Processing Record 528 | tallahassee
# Processing Record 529 | paciran
#  City Not Found. Skipping...
# Processing Record 530 | sao filipe
# Processing Record 531 | martapura
# Processing Record 532 | asyut
# Processing Record 533 | seoul
# Processing Record 534 | orcopampa
# Processing Record 535 | labuhan
# Processing Record 536 | blagoyevo
# Processing Record 537 | mogadishu
# Processing Record 538 | puerto narino
# Processing Record 539 | grand gaube
# Processing Record 540 | baykit
# Processing Record 541 | mitsamiouli
# Processing Record 542 | mayumba
# Processing Record 543 | tanakpur
# Processing Record 544 | bikaner
# Processing Record 545 | nikolayevsk-na-amure
# Processing Record 546 | rohtak
# Processing Record 547 | sturgis
# Processing Record 548 | hualmay
# Processing Record 549 | shetpe
# Processing Record 550 | blagoveshchensk
# Processing Record 551 | talwandi bhai
#  City Not Found. Skipping...
# Processing Record 552 | dryden
# Processing Record 553 | whitianga
# Processing Record 554 | adrar
# Processing Record 555 | gryazovets
# Processing Record 556 | nishihara
# Processing Record 557 | nome
# Processing Record 558 | jilin
# Processing Record 559 | port augusta
# Processing Record 560 | placido de castro
#  City Not Found. Skipping...
# Processing Record 561 | sorong
# Processing Record 562 | yulara
# Processing Record 563 | yurimaguas
# Processing Record 564 | rosa zarate
# Processing Record 565 | taltal
# Processing Record 566 | trinidad
# Processing Record 567 | kyaikto
# Processing Record 568 | san cristobal
# Processing Record 569 | kulhudhuffushi
#  City Not Found. Skipping...
# Processing Record 570 | tarata
# Processing Record 571 | ahuimanu
# Processing Record 572 | bayan
# Processing Record 573 | biltine
# Processing Record 574 | zhanaozen
#  City Not Found. Skipping...
# Processing Record 575 | broken hill
# Processing Record 576 | mgachi
#  City Not Found. Skipping...
# Processing Record 577 | bathsheba
# Processing Record 578 | srednekolymsk
# Processing Record 579 | champerico
# Processing Record 580 | livingston
# Processing Record 581 | gat
# Processing Record 582 | puerto asis
# Processing Record 583 | nurobod
# Processing Record 584 | cernay
# Processing Record 585 | hwange
# Processing Record 586 | tarnos
# Processing Record 587 | vestmannaeyjar
# Processing Record 588 | general roca
# Processing Record 589 | dunedin
# Processing Record 590 | mweka
# Processing Record 591 | kaoma
# Processing Record 592 | nosy varika
# Processing Record 593 | lavrentiya
# Processing Record 594 | lakes entrance
# Processing Record 595 | moore
# Processing Record 596 | magistralnyy
#  City Not Found. Skipping...
# Processing Record 597 | flin flon
# Processing Record 598 | pitmoaga
# Processing Record 599 | mwene-ditu
# Processing Record 600 | alvdal
# Processing Record 601 | mineiros
# Processing Record 602 | chumikan
# Processing Record 603 | babu
# Processing Record 604 | ouidah
# Processing Record 605 | charlestown
# Processing Record 606 | sudak
# Processing Record 607 | pitiquito
# Processing Record 608 | pizarro
# Processing Record 609 | rio gallegos
# Processing Record 610 | sanmenxia
# Processing Record 611 | fort nelson
# Processing Record 612 | changji
# Processing Record 613 | dicabisagan
# Processing Record 614 | usinsk
# Processing Record 615 | tromso
# Processing Record 616 | kondinskoye
# Processing Record 617 | nanortalik
# Processing Record 618 | vila franca do campo
# Processing Record 619 | puri
# Processing Record 620 | agutaya
# Processing Record 621 | klyuchi
# Processing Record 622 | vuktyl
# Processing Record 623 | alpena
# Processing Record 624 | libreville
# Processing Record 625 | omboue
# Processing Record 626 | kovdor
# Processing Record 627 | patacamaya
# Processing Record 628 | belgaum
# Processing Record 629 | tilichiki
# Processing Record 630 | izberbash
# Processing Record 631 | soyo
# Processing Record 632 | paharpur
# Processing Record 633 | bakchar
# Processing Record 634 | sri aman
# Processing Record 635 | awbari
# Processing Record 636 | palmer
# Processing Record 637 | zaysan
#  City Not Found. Skipping...
# Processing Record 638 | tura
# Processing Record 639 | gold coast
# Processing Record 640 | bull savanna
# Processing Record 641 | ixtapa
# Processing Record 642 | crixas
# Processing Record 643 | hokitika
# Processing Record 644 | wasilla
# Processing Record 645 | santa isabel
# Processing Record 646 | at-bashi
# Processing Record 647 | innisfail
# Processing Record 648 | camopi
# Processing Record 649 | poum
# Processing Record 650 | wuwei
# Processing Record 651 | manokwari
# Processing Record 652 | aden
# Processing Record 653 | neiafu
#  City Not Found. Skipping...
# Processing Record 654 | bonfim
# Processing Record 655 | okhotsk
# Processing Record 656 | mayo
# Processing Record 657 | rawson
# Processing Record 658 | fojnica
# Processing Record 659 | belaya gora
# Processing Record 660 | shirokiy
# Processing Record 661 | iracoubo
# Processing Record 662 | grootfontein
# Processing Record 663 | pulgaon
# Processing Record 664 | praia da vitoria
# Processing Record 665 | canavieiras
#  City Not Found. Skipping...
#  City Not Found. Skipping...
# Processing Record 666 | tobolsk
# Processing Record 667 | san antero
# Processing Record 668 | belyy
# Processing Record 669 | tessalit
# Processing Record 670 | sahuaripa
# Processing Record 671 | tulun
# Processing Record 672 | mahajanga
# Processing Record 673 | alekseyevsk
# Processing Record 674 | khash
# Processing Record 675 | kamenka
# Processing Record 676 | jinka
# Processing Record 677 | san policarpo
# Processing Record 678 | tazovskiy
#  City Not Found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Store the API call into dataframe
weather_data = pd.DataFrame({"City":city_name, 
                             "Cloudiness":cloud,
                             "Country":country,
                             "Date":date,
                             "Humidity":humidity,
                             "Lat":lat,
                             "Lng":lon,
                             "Max Temp":max_temperature,
                             "Wind Speed":wind})

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Check the dataframe
weather_data.count()
# Out:
# City          679
# Cloudiness    679
# Country       679
# Date          679
# Humidity      679
# Lat           679
# Lng           679
# Max Temp      679
# Wind Speed    679
# dtype: int64

# %%
# Display the dataframe
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Blackwater          20      GB  1548732000        86  51.33   -0.78
# 1       Kisesa          20      TZ  1548730800        83  -2.55   33.05
# 2       Lompoc          90      US  1548732900        93  34.64 -120.46
# 3  Yellowknife          20      CA  1548730800        67  62.45 -114.38
# 4     Bilibino          36      RU  1548733858        39  68.06  166.44
#
#    Max Temp  Wind Speed
# 0     33.80        4.70
# 1     69.80        8.75
# 2     59.00        3.36
# 3    -27.41        6.93
# 4    -26.33        2.37

# %%
# Add one column "readable date" to the dataframe 
weather_data["Date_readable"] = pd.to_datetime(weather_data["Date"],unit='s').dt.date

# Call the date from the readable date
t = weather_data["Date_readable"][1]

# Output File (CSV)
output_data_file = "output/cities.csv"
weather_data.to_csv(output_data_file, sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Define a function for plotting
def scatter_plot(weather_interest):
    return plt.scatter(weather_data["Lat"], weather_interest, linewidths = 1, marker = "o", label = i, facecolor = "blue", edgecolor = "black", alpha = 0.75), plt.xlabel("Latitude"),plt.grid()

# Plot the general fig
scatter_plot(weather_data["Max Temp"])

# Plot other features 
plt.ylabel("Max Temperautre(F)")
plt.title(f"City Latitude vs. Max Temperature ({t})")

# Save the fig
plt.savefig("output/City Latitude VS Max Temperature.png")

# Show plot
plt.show()

# %%
#####################################################################################################################################
#
#Figure "City Latitude vs. Max Temperature('the API calling time')" shows that 
#         1) the cities that are closer to equator have higher Max temperature (> 50 F)
#         2) the cities with latitude (20° - 80°) have lower temperature than the ones in (-20° ~ -60°)
#
#####################################################################################################################################

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot the fig with general feautres
scatter_plot(weather_data["Humidity"])

# Plot other features 
plt.ylim(top=105) # generally, no humidity is higher that 100%
plt.ylabel("Humidity(%)")
plt.title(f"City Latitude vs. Humidity ({t})")

# Save the fig
plt.savefig("output/City Latitude VS Humidity.png")

# Show plot
plt.show()

# %%
##########################################################################################################################
#
#Figure "City Latitude vs. Humidity ('the API calling time')" shows that the cities with latitude (20° ~ 60°)have higher humidity(60%-100%)
#
##########################################################################################################################

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot the fig with general feautres
scatter_plot(weather_data["Cloudiness"])

# Plot other features 
plt.ylim(top=105) # generally, no cloudiness is higher that 100%
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs. Cloudiness ({t})")

# Save the fig
plt.savefig("output/City Latitude VS Cloudiness.png")

# Show plot
plt.show()

# %%
################################################################################################################################################
#
#Figure "City Latitude vs. Cloudiness ('the API calling time')" shows that the cloudiness of cities does not significantly vary with location
#
################################################################################################################################################

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot the fig with general feautres
scatter_plot(weather_data["Wind Speed"])

# Plot other features 
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed({t})")

# Save the fig
plt.savefig("output/City Latitude VS Wind Speed.png")

# Show plot
plt.show()

# %%
##########################################################################################################################
#
#Figure "City Latitude vs. Wind Speed ('the API calling time')" shows that 
#      1) the windspeed of the cities are generally lower than 25 mph
#      2) cities withe latitude higher than 60° are more higher higher wind speed (>25 mph)
#
##########################################################################################################################
